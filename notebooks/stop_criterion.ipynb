# %% [markdown]
# Run the next cell to visualize original loss graphs

# %%
import sys
sys.path.append('/nfs/proc/isabelle.melo/Mosquitoes/faster_detectron')
from codes.stop_criterion import plot_loss

root = '/home/isabelle.melo/proc/Mosquitoes/faster_detectron2_copy/outputs/faster_rcnn_R_50_FPN_1x/v2_tire_40m_5folds_flag_True_aug'
model = 'faster_rcnn_R_50_FPN_1x'
obj = 'tire'
fold = 0

plot_loss(root, model, obj, fold)

# %% [markdown]
# Run the next cell to visualize the results of stop criterion algorithm. You can change window_size, tolerance and min_iteration to see if you can get better results. Choose a set of "optimal parameters" after visualization

# %%
from stop_criterion import plot_stop_criterion

root = '/home/isabelle.melo/proc/Mosquitoes/faster_detectron2/outputs/faster_rcnn_R_50_FPN_1x/new_lr002_pooler7_bpi32_ipb4'
model = 'faster_rcnn_R_50_FPN_1x'
obj = 'tire'
window_size = 50 
tolerance = 0.00001 
min_iteration = 1000 
folds = 8

plot_stop_criterion(root, model, obj, window_size, tolerance, min_iteration, folds)
# Out:
# 0.005596143653747276
# 0.0037672840408049524
# 0.003272248707617109
# 0.03488279413431883
# 0.0017179646220029099
# 0.0006644439199590124
# 0.007471447112038732
# 0.007065263675031019
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
